# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale
from matplotlib.colors import ListedColormap
from sklearn.cluster import KMeans

# %%
countriesDat = pd.read_csv('Country-data.csv')
countriesDat
# Out:
#                  country  child_mort  exports  health  imports  income  \
# 0            Afghanistan        90.2     10.0    7.58     44.9    1610
# 1                Albania        16.6     28.0    6.55     48.6    9930
# 2                Algeria        27.3     38.4    4.17     31.4   12900
# 3                 Angola       119.0     62.3    2.85     42.9    5900
# 4    Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
# ..                   ...         ...      ...     ...      ...     ...
# 162              Vanuatu        29.2     46.6    5.25     52.7    2950
# 163            Venezuela        17.1     28.5    4.91     17.6   16500
# 164              Vietnam        23.3     72.0    6.84     80.2    4490
# 165                Yemen        56.3     30.0    5.18     34.4    4480
# 166               Zambia        83.1     37.0    5.89     30.9    3280
#
#      inflation  life_expec  total_fer   gdpp
# 0         9.44        56.2       5.82    553
# ...

# %% [markdown]
# # Data analysis

# %%
countriesDat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167 entries, 0 to 166
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     167 non-null    object
#  1   child_mort  167 non-null    float64
#  2   exports     167 non-null    float64
#  3   health      167 non-null    float64
#  4   imports     167 non-null    float64
#  5   income      167 non-null    int64
#  6   inflation   167 non-null    float64
#  7   life_expec  167 non-null    float64
#  8   total_fer   167 non-null    float64
#  9   gdpp        167 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 13.2+ KB

# %%
countriesDat.isnull().sum()
# Out:
# country       0
# child_mort    0
# exports       0
# health        0
# imports       0
# income        0
# inflation     0
# life_expec    0
# total_fer     0
# gdpp          0
# dtype: int64

# %%
countriesDat.columns
# Out:
# Index(['country', 'child_mort', 'exports', 'health', 'imports', 'income',
#        'inflation', 'life_expec', 'total_fer', 'gdpp'],
#       dtype='object')

# %% [markdown]
# ### 10 Countries with largest gdpp

# %%
countriesDat.nlargest(10, ['gdpp'])
# Out:
#            country  child_mort  exports  health  imports  income  inflation  \
# 91      Luxembourg         2.8    175.0    7.77    142.0   91700      3.620
# 114         Norway         3.2     39.7    9.48     28.5   62300      5.950
# 145    Switzerland         4.5     64.0   11.50     53.3   55500      0.317
# 123          Qatar         9.0     62.3    1.81     23.8  125000      6.980
# 44         Denmark         4.1     50.5   11.40     43.6   44000      3.220
# 144         Sweden         3.0     46.2    9.63     40.7   42900      0.991
# 7        Australia         4.8     19.8    8.73     20.9   41400      1.160
# 110    Netherlands         4.5     72.0   11.90     63.6   45500      0.848
# 73         Ireland         4.2    103.0    9.19     86.5   45700     -3.220
# 159  United States         7.3     12.4   17.90     15.8   49400      1.220
#
#      life_expec  total_fer    gdpp
# 91         81.3       1.63  105000
# 114        81.0       1.95   87800
# ...

# %% [markdown]
# ### 10 Countries with smallest gdpp

# %%
countriesDat.nsmallest(10, ['gdpp'])
# Out:
#                       country  child_mort  exports  health  imports  income  \
# 26                    Burundi        93.6     8.92   11.60     39.2     764
# 88                    Liberia        89.3    19.10   11.80     92.6     700
# 37           Congo, Dem. Rep.       116.0    41.10    7.91     49.6     609
# 112                     Niger       123.0    22.20    5.16     49.1     814
# 132              Sierra Leone       160.0    16.80   13.10     34.5    1220
# 93                 Madagascar        62.2    25.00    3.77     43.0    1390
# 106                Mozambique       101.0    31.50    5.21     46.2     918
# 31   Central African Republic       149.0    11.80    3.98     26.5     888
# 94                     Malawi        90.5    22.80    6.59     34.9    1030
# 50                    Eritrea        55.2     4.79    2.66     23.3    1420
#
#      inflation  life_expec  total_fer  gdpp
# 26       12.30        57.7       6.26   231
# ...

# %% [markdown]
# ### 10 Countries with largest life expectancy

# %%
countriesDat.nlargest(10, ['life_expec'])
# Out:
#          country  child_mort  exports  health  imports  income  inflation  \
# 77         Japan         3.2     15.0    9.49     13.6   35800     -1.900
# 133    Singapore         2.8    200.0    3.96    174.0   72100     -0.046
# 145  Switzerland         4.5     64.0   11.50     53.3   55500      0.317
# 7      Australia         4.8     19.8    8.73     20.9   41400      1.160
# 68       Iceland         2.6     53.4    9.40     43.3   38800      5.470
# 139        Spain         3.8     25.5    9.54     26.8   32500      0.160
# 75         Italy         4.0     25.2    9.53     27.2   36200      0.319
# 144       Sweden         3.0     46.2    9.63     40.7   42900      0.991
# 54        France         4.2     26.8   11.90     28.1   36900      1.050
# 74        Israel         4.6     35.0    7.63     32.9   29600      1.770
#
#      life_expec  total_fer   gdpp
# 77         82.8       1.39  44500
# 133        82.7       1.15  46600
# 145        82.2       1.52  74600
# ...

# %% [markdown]
# ### 10 Countries with smallest life expectancy

# %%
countriesDat.nsmallest(10, ['life_expec'])
# Out:
#                       country  child_mort  exports  health  imports  income  \
# 66                      Haiti       208.0     15.3    6.91     64.7    1500
# 87                    Lesotho        99.7     39.4   11.10    101.0    2380
# 31   Central African Republic       149.0     11.8    3.98     26.5     888
# 166                    Zambia        83.1     37.0    5.89     30.9    3280
# 94                     Malawi        90.5     22.8    6.59     34.9    1030
# 137              South Africa        53.7     28.6    8.94     27.4   12000
# 106                Mozambique       101.0     31.5    5.21     46.2     918
# 132              Sierra Leone       160.0     16.8   13.10     34.5    1220
# 64              Guinea-Bissau       114.0     14.9    8.50     35.2    1390
# 0                 Afghanistan        90.2     10.0    7.58     44.9    1610
#
#      inflation  life_expec  total_fer  gdpp
# 66        5.45        32.1       3.33   662
# ...

# %% [markdown]
# ## Correlations

# %%
corrs = countriesDat.corr()
plt.figure(figsize=(16,12))
cmap = sns.color_palette("Reds", as_cmap=True)
h1 = sns.heatmap(corrs, center=0, annot=True, fmt='.2f', square=True, cmap='PiYG')

# %% [markdown]
# ## One-way Analysis

# %%
sns.boxplot(x=countriesDat['health'], color = 'purple')
# Out:
# <AxesSubplot:xlabel='health'>

# %%
healthDat = countriesDat[countriesDat['health']<14]
sns.histplot(data=healthDat, x='health', color="purple", bins = 25)
# Out:
# <AxesSubplot:xlabel='health', ylabel='Count'>

# %%
inflDat = countriesDat['inflation']
sns.histplot(data=inflDat, color="purple", bins = 25)
# Out:
# <AxesSubplot:xlabel='inflation', ylabel='Count'>

# %%
inflDatExt = countriesDat[countriesDat['inflation']<35]
sns.histplot(data=inflDatExt,  x="inflation", color="purple", bins = 25)
# Out:
# <AxesSubplot:xlabel='inflation', ylabel='Count'>

# %%
inflDat = countriesDat['gdpp']
sns.histplot(data=inflDat, color="purple", bins = 25)
# Out:
# <AxesSubplot:xlabel='gdpp', ylabel='Count'>

# %%
gdppDat = countriesDat[countriesDat['gdpp'] < 40000]
sns.histplot(data=gdppDat, x="gdpp", color="purple", bins = 50)
# Out:
# <AxesSubplot:xlabel='gdpp', ylabel='Count'>

# %% [markdown]
# ## Two-way Analysis

# %%
sns.scatterplot(data = countriesDat, x = "total_fer", y = "child_mort", color = 'purple')
sns.rugplot(data = countriesDat, x = "total_fer", y = "child_mort", color = 'purple')
# Out:
# <AxesSubplot:xlabel='total_fer', ylabel='child_mort'>

# %%
sns.scatterplot(data=countriesDat, x="gdpp", y="life_expec", color = 'purple')
# Out:
# <AxesSubplot:xlabel='gdpp', ylabel='life_expec'>

# %%
sns.scatterplot(data=countriesDat, x="gdpp", y="income", color = 'purple')
# Out:
# <AxesSubplot:xlabel='gdpp', ylabel='income'>

# %%
sns.scatterplot(data=countriesDat, x="imports", y="exports",color = 'purple')
# Out:
# <AxesSubplot:xlabel='imports', ylabel='exports'>

# %% [markdown]
# ## Detect and remove the emissions

# %%
fig = plt.figure()
sns.boxplot(x=countriesDat ['child_mort'])
plt.style.use('dark_background')
plt.show()

# %%
sns.boxplot(x=countriesDat['gdpp'])
plt.style.use('dark_background')
plt.show()

# %%
sns.boxplot(x=countriesDat['income'])
plt.style.use('dark_background')
plt.show()

# %%
clearDat = countriesDat[["country",'gdpp','child_mort','income']]
clearDat = clearDat[clearDat['gdpp'] < 55000]
clearDat = clearDat[clearDat['child_mort'] < 140]
clearDat = clearDat[clearDat['income'] < 50000]
clearDat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 154 entries, 0 to 166
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     154 non-null    object
#  1   gdpp        154 non-null    int64
#  2   child_mort  154 non-null    float64
#  3   income      154 non-null    int64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# ## Clustering with k-mean method

# %%
clust = list(zip(clearDat["gdpp"], clearDat["income"]))
inertias = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(clust)
    inertias.append(kmeans.inertia_)

# %%
plt.plot(range(1,11), inertias, marker='x', color = 'purple')
plt.title('Elbow method')
plt.xlabel('Count of clusters')
plt.ylabel('Inertion')
plt.show()

# %%
clust2 = list(zip(clearDat["gdpp"], clearDat["child_mort"]))
inertias = []

for i in range(1,11):
    kmeans = KMeans(n_clusters=i)
    kmeans.fit(clust2)
    inertias.append(kmeans.inertia_)

# %%
plt.plot(range(1,11), inertias, marker='x', color = 'purple')
plt.title('Elbow method')
plt.xlabel('Count of clusters')
plt.ylabel('Inertion')
plt.show()

# %%
cmeans = KMeans(n_clusters=2)
kmeans.fit(clust)
fig, ax = plt.subplots(figsize=(8, 6))
plt.scatter(clearDat["gdpp"], clearDat["income"], c=kmeans.labels_, cmap='PiYG')
ax.set_xlabel('gdpp')
ax.set_ylabel('income')
plt.show()

# %%
clearDat.nsmallest(10, ['income', 'gdpp'])
# Out:
#               country  gdpp  child_mort  income
# 37   Congo, Dem. Rep.   334       116.0     609
# 88            Liberia   327        89.3     700
# 26            Burundi   231        93.6     764
# 112             Niger   348       123.0     814
# 106        Mozambique   419       101.0     918
# 94             Malawi   459        90.5    1030
# 63             Guinea   648       109.0    1190
# 150              Togo   488        90.3    1210
# 126            Rwanda   563        63.6    1350
# 93         Madagascar   413        62.2    1390

# %%
CI = clearDat[['child_mort', 'income']].copy()
from sklearn.mixture import GaussianMixture
n_clusters = 3
gmm_model = GaussianMixture(n_components=n_clusters)
gmm_model.fit(CI)
cluster_labels = gmm_model.predict(CI)
CI = pd.DataFrame(CI)
CI['cluster'] = cluster_labels

# %%
fig, ax = plt.subplots(figsize=(9, 7))
sns.scatterplot(x='child_mort', y='income', data=CI, hue='cluster', cmap='PiYG', s=70, ax = ax) 
plt.title('Clusters Identified by Guassian Mixture Model')
plt.ylabel('child_mort')
plt.xlabel('income')
# Out:
# Text(0.5, 0, 'income')

# %% [markdown]
# ## 5 countries with worst values

# %%
badCount = clearDat[["country"]]
badCount=pd.merge(badCount,CI, left_index=True,right_index=True)
badCount.nsmallest(5, ['income', 'child_mort'])
# Out:
#               country  child_mort  income  cluster
# 37   Congo, Dem. Rep.       116.0     609        1
# 88            Liberia        89.3     700        1
# 26            Burundi        93.6     764        1
# 112             Niger       123.0     814        1
# 106        Mozambique       101.0     918        1

# %%
badCount['cluster'].value_counts(normalize=True)
# Out:
# 0    0.532468
# 1    0.318182
# 2    0.149351
# Name: cluster, dtype: float64

# %%
Cluster_child_mort=pd.DataFrame(CI.groupby(["cluster"]).child_mort.mean())
Cluster_income=pd.DataFrame(CI.groupby(["cluster"]).income.mean())
CMI = pd.concat([Cluster_child_mort,Cluster_income], axis=1)
CMI.columns = ["child_mort","income"]
CMI
# Out:
#          child_mort        income
# cluster
# 0         10.778049  22376.951220
# 1         78.665306   2487.653061
# 2         40.408696  10296.521739

# %%
fig = plt.figure(figsize = (10,6))
CMI.rename(index={2: 'High developes countries'},inplace=True)
CMI.rename(index={1: 'Developing countries'},inplace=True)
CMI.rename(index={0: 'Low developed countries'},inplace=True)
s=sns.barplot(x=CMI.index,y='income',data=CMI)
plt.xlabel('Groups', fontsize=10)
plt.ylabel('Income per person', fontsize=10)
plt.title('Group countries by income')
plt.show()

# %%
greatCon=badCount[badCount['cluster']==2]
normCon=badCount[badCount['cluster']==1]
badCon=badCount[badCount['cluster']==0]
badCon=badCon.sort_values(by = 'income')

fig = plt.figure(figsize = (12,6))
s=sns.barplot(x='country',y='income',data=badCon)

s.set_xticklabels(s.get_xticklabels(),rotation=90)
plt.xlabel('Country', fontsize=10)
plt.ylabel('Income per person', fontsize=10)
plt.title('Income per person in low-developed countries')
plt.show()
